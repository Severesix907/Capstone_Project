# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('gsearch_jobs-Jianhang.csv')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0  index                                              title  \
# 0               0      0                                       Data Analyst
# 1               1      1  Junior Data Analyst/Scientist Role - Contract ...
# 2               2      2                                       Data Analyst
# 3               3      3                                       Data Analyst
# 4               4      4                                       Data Analyst
# ...           ...    ...                                                ...
# 48097       48097   1458                     Marketing Data & BI Analyst II
# 48098       48098   1459                                  Lead-Data Analyst
# 48099       48099   1460                                  Lead-Data Analyst
# 48100       48100   1461                                  Lead-Data Analyst
# 48101       48101   1462  Institutional Credit Management - Lending Data...
#
# ...

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0         index         title company_name    location  \
# count   48102.000000  48102.000000         48102        48102       48067
# unique           NaN           NaN         17754        10963         822
# top              NaN           NaN  Data Analyst       Upwork   Anywhere
# freq             NaN           NaN          5748         6897       15679
# mean    24050.500000   1121.988545           NaN          NaN         NaN
# std     13885.995661    682.978210           NaN          NaN         NaN
# min         0.000000      0.000000           NaN          NaN         NaN
# 25%     12025.250000    546.000000           NaN          NaN         NaN
# 50%     24050.500000   1093.000000           NaN          NaN         NaN
# 75%     36075.750000   1648.000000           NaN          NaN         NaN
# max     48101.000000   3044.000000           NaN          NaN         NaN
#
#                  via                                        description  \
# ...

# %%
df[['salary_avg', 'salary_min', 'salary_max']].describe()
# Out:
#           salary_avg     salary_min     salary_max
# count    8246.000000    7801.000000    7801.000000
# mean    37705.446712   31292.172292   44766.377350
# std     52999.755790   44050.733795   62793.432872
# min         7.250000       8.000000      10.000000
# 25%        30.500000      18.460000      43.000000
# 50%        57.500000      40.000000      75.000000
# 75%     87500.000000   75000.000000  100000.000000
# max    300000.000000  275000.000000  346000.000000

# %%
df.drop(columns=['commute_time','Unnamed: 0','index', 'thumbnail'],axis=1, inplace=True)#drop columns that are irrevelant

# %%
df.sample
# Out:
# <bound method NDFrame.sample of                                                    title      company_name  \
# 0                                           Data Analyst           Chloeta
# 1      Junior Data Analyst/Scientist Role - Contract ...            Upwork
# 2                                           Data Analyst               ATC
# 3                                           Data Analyst        Guidehouse
# 4                                           Data Analyst  AnMed Health LLC
# ...                                                  ...               ...
# 48097                     Marketing Data & BI Analyst II      EDWARD JONES
# 48098                                  Lead-Data Analyst      EDWARD JONES
# 48099                                  Lead-Data Analyst      EDWARD JONES
# 48100                                  Lead-Data Analyst      EDWARD JONES
# 48101  Institutional Credit Management - Lending Data...              Citi
#
# ...

# %%
df.head(5)
# Out:
#                                                title      company_name  \
# 0                                       Data Analyst           Chloeta
# 1  Junior Data Analyst/Scientist Role - Contract ...            Upwork
# 2                                       Data Analyst               ATC
# 3                                       Data Analyst        Guidehouse
# 4                                       Data Analyst  AnMed Health LLC
#
#                  location               via  \
# 0    Oklahoma City, OK     via ZipRecruiter
# 1               Anywhere         via Upwork
# 2        United States         via LinkedIn
# 3           Topeka, KS            via Nexxt
# 4               Anywhere       via LinkedIn
#
#                                          description  \
# 0  Job Summary: The Data Analyst oversees data pr...
# 1  Company\n\nThe TAC Index provides independent,...
# 2  Job Title: Entry Level Business Analyst / Prod...
# ...

# %%
df['title'].nunique()
# Out:
# 17754

# %%
df['title'].unique().tolist()
# Out:
# ['Data Analyst',
#  'Junior Data Analyst/Scientist Role - Contract to hire',
#  'Research Data Analyst 1',
#  'Healthcare Data Analyst',
#  'Associate Data Analyst',
#  'Data Growth Analyst & Insights Manager',
#  'Data Analyst I (Healthcare Analytics)',
#  'Data Scientist - Contract to hire',
#  'Senior Data Analyst',
#  'Sr Data Analyst',
#  'Site Reliability Engineer I, Analytics and Data',
#  'Data analyst/Sales representative(W2 Contract)',
#  'Data Analyst Report Writer (Level 2) _ Austin, TX/Remote (Prefers...',
#  'Product Data Analyst',
#  'Data Analyst, Report Writer',
#  'Zoho Analytics transform SQL (records for every day between two...',
#  'Data Scientist II (Consumer Lending)',
#  'Mixpanel Expert - setup and configuration',
#  'Data Analyst, Strategy',
#  'GIS & Urban planning research',
#  'Senior Data Analyst (SQL, Tableau, Business Fluency)',
#  'Sr. Financial Data Analyst with Security Clearance',
#  'Associate Research/Data Analyst-CES - Now Hiring',
# ...

# %%
#df2=df['title'].filter(regex='Analyst')
#df2

# %%
data_analyst=df[df.title.str.lower().str.contains('data analyst')]
data_analyst
# Out:
#                                                    title       company_name  \
# 0                                           Data Analyst            Chloeta
# 1      Junior Data Analyst/Scientist Role - Contract ...             Upwork
# 2                                           Data Analyst                ATC
# 3                                           Data Analyst         Guidehouse
# 4                                           Data Analyst   AnMed Health LLC
# ...                                                  ...                ...
# 48096                                    Sr Data Analyst  Kforce Technology
# 48098                                  Lead-Data Analyst       EDWARD JONES
# 48099                                  Lead-Data Analyst       EDWARD JONES
# 48100                                  Lead-Data Analyst       EDWARD JONES
# 48101  Institutional Credit Management - Lending Data...               Citi
#
#                      location                    via  \
# ...

# %%
data_scientist=df[df.title.str.lower().str.contains('data scientist')]
data_scientist
# Out:
#                                                    title     company_name  \
# 13                     Data Scientist - Contract to hire           Upwork
# 23                  Data Scientist II (Consumer Lending)         Pathward
# 36                  Data Scientist II (Consumer Lending)         Pathward
# 48                  Data Scientist II (Consumer Lending)         Pathward
# 57     Expert Marketing Data Scientist - Market Mix M...           Upwork
# ...                                                  ...              ...
# 47110  Senior Data Scientist - Supply Chain (Sam's Club)       Sam's Club
# 47111  Senior Data Scientist - Supply Chain (Sam's Club)       Sam's Club
# 47112  Senior Data Scientist - Supply Chain (Sam's Club)       Sam's Club
# 47113  Senior Data Scientist - Supply Chain (Sam's Club)       Sam's Club
# 47723  Remote Data Scientist (Data Analyst Applicatio...  SES Corporation
#
#               location                   via  \
# ...

# %%
data_engineer=df[df.title.str.lower().str.contains('data engineer')]
data_engineer
# Out:
#                                       title            company_name  \
# 33     Sr. Category Analyst - Data Engineer   Ghirardelli Chocolate
# 83                            Data Engineer         Impact Advisors
# 189                       Data Engineer III                 Walmart
# 191                       Data Engineer III                 Walmart
# 193                       Data Engineer III                 Walmart
# ...                                     ...                     ...
# 46556             Sr Analyst, Data Engineer  Estee Lauder Companies
# 47108            (USA) Senior Data Engineer                 Walmart
# 47610             Sr Analyst, Data Engineer  Estee Lauder Companies
# 47634             Sr Analyst, Data Engineer  Estee Lauder Companies
# 48011                 Data Engineer/Analyst            Techveda Inc
#
#                    location                    via  \
# 33            Rogers, AR          via ZipRecruiter
# ...

# %%
df['extensions']
# Out:
# 0        ['21 hours ago', 'Full-time', 'Health insuranc...
# 1        ['17 hours ago', 'Work from home', 'Contractor...
# 2        ['12 hours ago', 'Full-time', 'Health insurance']
# 3        ['10 hours ago', 'Full-time', 'Health insuranc...
# 4        ['18 hours ago', 'Work from home', 'Part-time'...
#                                ...
# 48097    ['23 hours ago', '76,798–130,764 a year', 'Ful...
# 48098    ['23 hours ago', '106,916–182,047 a year', 'Fu...
# 48099    ['23 hours ago', '106,916–182,047 a year', 'Fu...
# 48100    ['23 hours ago', '106,916–182,047 a year', 'Fu...
# 48101    ['24 hours ago', '105,850–158,780 a year', 'Fu...
# Name: extensions, Length: 48102, dtype: object

# %%
df.shape
# Out:
# (48102, 23)

# %%
df.columns
# Out:
# Index(['title', 'company_name', 'location', 'via', 'description', 'extensions',
#        'job_id', 'posted_at', 'schedule_type', 'work_from_home', 'salary',
#        'search_term', 'date_time', 'search_location', 'salary_pay',
#        'salary_rate', 'salary_avg', 'salary_min', 'salary_max',
#        'salary_hourly', 'salary_yearly', 'salary_standardized',
#        'description_tokens'],
#       dtype='object')

# %%
df.dtypes
# Out:
# title                   object
# company_name            object
# location                object
# via                     object
# description             object
# extensions              object
# job_id                  object
# posted_at               object
# schedule_type           object
# work_from_home          object
# salary                  object
# search_term             object
# date_time               object
# search_location         object
# salary_pay              object
# salary_rate             object
# salary_avg             float64
# salary_min             float64
# salary_max             float64
# salary_hourly          float64
# salary_yearly          float64
# salary_standardized    float64
# description_tokens      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# title                      0
# company_name               0
# location                  35
# via                        9
# description                0
# extensions                 0
# job_id                     0
# posted_at                  0
# schedule_type            184
# work_from_home         25329
# salary                 39856
# search_term                0
# date_time                  0
# search_location            0
# salary_pay             39856
# salary_rate            39856
# salary_avg             39856
# salary_min             40301
# salary_max             40301
# salary_hourly          42926
# salary_yearly          45058
# salary_standardized    39856
# description_tokens         0
# dtype: int64

# %%
# Convert 'salary_pay' column to numeric values
#df['salary_pay'] = pd.to_numeric(df['salary_pay'], errors='coerce')

# Calculate the mean of the column
#mean_value = df['salary_pay'].mean()

# Fill missing values with the mean
#df['salary_pay'].fillna(value=mean_value, inplace=True)

# %%
#df['salary_pay'].fillna(0, inplace=True)

# %%
#df['salary_avg'] = pd.to_numeric(df['salary_avg'], errors='coerce')
#mean_value = df['salary_avg'].mean()
#df['salary_avg'].fillna(value=mean_value, inplace=True)

# %%
#df['salary_min'] = pd.to_numeric(df['salary_min'], errors='coerce')
#mean_value = df['salary_min'].mean()
#df['salary_min'].fillna(value=mean_value, inplace=True)

# %%
#df['salary_max'] = pd.to_numeric(df['salary_max'], errors='coerce')
#mean_value = df['salary_max'].mean()
#df['salary_max'].fillna(value=mean_value, inplace=True)

# %%
#df['salary_hourly'] = pd.to_numeric(df['salary_hourly'], errors='coerce')
#mean_value = df['salary_hourly'].mean()
#df['salary_hourly'].fillna(value=mean_value, inplace=True)

# %%
#df['salary_hourly'] = pd.to_numeric(df['salary_hourly'], errors='coerce')
#mean_value = df['salary_hourly'].mean()
#df['salary_hourly'].fillna(value=mean_value, inplace=True)

# %%
#df['salary_yearly'] = pd.to_numeric(df['salary_yearly'], errors='coerce')
#mean_value = df['salary_yearly'].mean()
#df['salary_yearly'].fillna(value=mean_value, inplace=True)

# %%
#df['salary_standardized'] = pd.to_numeric(df['salary_standardized'], errors='coerce')
#mean_value = df['salary_standardized'].mean()
#df['salary_standardized'].fillna(value=mean_value, inplace=True)

# %%
df.isnull().sum() #title, data time, descroption token, and salary standarized are the most important columns.
# Out:
# title                      0
# company_name               0
# location                  35
# via                        9
# description                0
# extensions                 0
# job_id                     0
# posted_at                  0
# schedule_type            184
# work_from_home         25329
# salary                 39856
# search_term                0
# date_time                  0
# search_location            0
# salary_pay             39856
# salary_rate            39856
# salary_avg             39856
# salary_min             40301
# salary_max             40301
# salary_hourly          42926
# salary_yearly          45058
# salary_standardized    39856
# description_tokens         0
# dtype: int64

# %%
df[['salary_avg', 'salary_min', 'salary_max']].describe()
# Out:
#           salary_avg     salary_min     salary_max
# count    8246.000000    7801.000000    7801.000000
# mean    37705.446712   31292.172292   44766.377350
# std     52999.755790   44050.733795   62793.432872
# min         7.250000       8.000000      10.000000
# 25%        30.500000      18.460000      43.000000
# 50%        57.500000      40.000000      75.000000
# 75%     87500.000000   75000.000000  100000.000000
# max    300000.000000  275000.000000  346000.000000

# %%
df['salary_pay'] = pd.to_numeric(df['salary_pay'], errors='coerce')

# %%
df['salary_pay'].mean()
# Out:
# 10102.517095808384

# %%
# Check the sample size. since there are a lot of missing values, find the percent of jobs with salaries Pay
total_jobs = len(df)
jobs_with_salaries = df['salary_pay'].count()

percent_jobs_with_salaries = (jobs_with_salaries / total_jobs) * 100
percent_jobs_with_salaries
# Out:
# 0.6943578229595443

# %%
columns_to_delete = ["work_from_home", "salary", "salary_pay", "salary_rate", "salary_avg", 
                     "salary_min", "salary_max", "salary_hourly", "salary_yearly"]

df = df.drop(columns=columns_to_delete)

# %%
# Check the sample size. since there are a lot of missing values, find the percent of jobs with salary standarized
total_jobs = len(df)
jobs_with_salaries = df['salary_standardized'].count()

percent_jobs_with_salaries = (jobs_with_salaries / total_jobs) * 100
percent_jobs_with_salaries
# Out:
# 17.142738347677852

# %%
# Check for outliers in the salary by creating a box plot
sns.set(style="whitegrid")  

plt.figure(figsize=(8, 6))
sns.boxplot(y=df['salary_standardized'])

plt.xlabel('Salary Standarized')
plt.title('Box Plot of Salary Standarized with Outliers')

plt.show()

# %%
df['schedule_type'].unique()
# Out:
# array(['Full-time', 'Contractor', 'Part-time', nan, 'Internship',
#        'Part-time and Internship', 'Contractor and Temp work',
#        'Full-time and Part-time', 'Full-time and Temp work',
#        'Full-time and Contractor', 'Temp work',
#        'Full-time and Internship', 'Part-time and Temp work',
#        'Full-time, Part-time, and Contractor',
#        'Full-time, Contractor, and Temp work',
#        'Part-time, Contractor, and Temp work', 'Part-time and Contractor',
#        'Temp work and Internship', 'Volunteer',
#        'Full-time, Part-time, and Internship', 'Part-time and Full-time',
#        'Full-time and Per diem', 'Part-time, Temp work, and Internship',
#        'Temp work and Per diem', 'Contractor and Per diem',
#        'Full-time and Volunteer', 'Full-time, Part-time, and Per diem',
#        'Full-time, Temp work, and Internship',
#        'Full-time, Part-time, and Temp work', 'Part-time and Per diem',
# ...

# %%
# Count the frequency of each unique schedule type
schedule_counts = df['schedule_type'].value_counts()

# Plotting the histogram
plt.figure(figsize=(10, 6))  
plt.bar(schedule_counts.index, schedule_counts.values)
plt.xlabel('Schedule Type')
plt.ylabel('Frequency')
plt.title('Frequency of Schedule Types')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlap of labels
plt.show()

# %%
df[''].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\xiaoj\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\xiaoj\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\xiaoj\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['title'].value_counts()
# Out:
# title
# Data Analyst                                                     5748
# Senior Data Analyst                                              1539
# Data Scientist                                                    767
# Data Analyst II                                                   536
# Business Data Analyst                                             445
#                                                                  ...
# Data Analyst Senior - BIS                                           1
# Data Analyst/Data Visualization (PowerBI)                           1
# Business Analyst/Data Analyst with Informatica/MDM experience       1
# Fulfillment Technology  Data Analyst                                1
# Lead FP&A Analyst- Remote, US                                       1
# Name: count, Length: 17754, dtype: int64

# %%
# Group the data by job title and calculate the average salary for each title
avg_salary_by_title = df.groupby('title')['salary_avg'].mean()

# Sort the data in descending order and select the top 10
top_10 = avg_salary_by_title.sort_values(ascending=False).head(10)


plt.figure(figsize=(12,8))
plt.bar(top_10.index, top_10.values)
plt.xticks(rotation=90)
plt.xlabel('Job Title')
plt.ylabel('Average Salary ($)')
plt.title('Top 10 Job Titles with the Highest Average Salary')
plt.show()

# %%
avg_salary_by_title = df.groupby('title')['schedule_type'].count()

# Sort the data in descending order and select the top 10
top_10 = avg_salary_by_title.sort_values(ascending=False).head(10)


plt.figure(figsize=(12,8))
plt.bar(top_10.index, top_10.values)
plt.xticks(rotation=90)
plt.xlabel('Job Title')
plt.ylabel('schedule_type')
plt.title('Top 10 Job Titles with the schedule_type')
plt.show()

# %%
avg_salary_by_title = df.groupby('title')['work_from_home'].count()

# Sort the data in descending order and select the top 10
top_10 = avg_salary_by_title.sort_values(ascending=False).head(10)


plt.figure(figsize=(12,8))
plt.bar(top_10.index, top_10.values)
plt.xticks(rotation=90)
plt.xlabel('Job Title')
plt.ylabel('work_from_home')
plt.title('Top 10 Job Titles with the work_from_home')
plt.show()

# %%
df['company_name'].value_counts()#some jobs are not real jobs. are staffing agent. we need to talk about this. drop or keep some of staffing agencies.
# Out:
# company_name
# Upwork                      6897
# Talentify.io                1656
# Walmart                     1536
# EDWARD JONES                 747
# Dice                         673
#                             ...
# AtlasDIY                       1
# pulseData                      1
# Ritchie Bros Auctioneers       1
# Summit Utilities               1
# Techdash Telecom               1
# Name: count, Length: 10963, dtype: int64

# %%
df = df[~df['company_name'].isin(['Upwork', 'Talentify.io'])]

# %%
#df.drop(['Unnamed: 0','index','extensions','job_id','thumbnail','commute_time'],axis=1,inplace=True)

# %%
df
# Out:
#                                                    title  \
# 0                                           Data Analyst
# 2                                           Data Analyst
# 3                                           Data Analyst
# 4                                           Data Analyst
# 5                                Research Data Analyst 1
# ...                                                  ...
# 48097                     Marketing Data & BI Analyst II
# 48098                                  Lead-Data Analyst
# 48099                                  Lead-Data Analyst
# 48100                                  Lead-Data Analyst
# 48101  Institutional Credit Management - Lending Data...
#
#                              company_name                location  \
# 0                                 Chloeta    Oklahoma City, OK
# 2                                     ATC        United States
# 3                              Guidehouse           Topeka, KS
# ...

# %%
for col in df.select_dtypes('float64'): #the distribution of qualitative variables
    plt.figure(figsize=(10,5))
    sns.displot(df[col], color='blue')#is this for 2022 or all years??
# Out:
# c:\Users\xiaoj\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\xiaoj\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\xiaoj\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\xiaoj\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\xiaoj\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\xiaoj\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %%
jobs_by_location = df.groupby('location')['title'].count()
top_10 = jobs_by_location.sort_values(ascending=False).head(10)
plt.figure(figsize=(12,8))
plt.bar(top_10.index, top_10.values)
plt.xticks(rotation=90)
plt.xlabel('Location')
plt.ylabel('Number of Job Postings')
plt.title('Distribution of Data Analyst Job Postings by Location')
plt.show()

# %%
unique_states=set(item for item in df["location"]) #look for unique states
print(unique_states)
# Out:
# {'  Prairie Grove, AR   ', 'Pea Ridge, AR', '  Lake Quivira, KS   ', 'New York Township, MO', '  Bella Vista, AR   ', 'Pleasant Hope, MO', 'Home, KS', '  Newcastle, OK   ', '  McGirk, MO   ', '  Garfield, AR   ', 'Kiefer, OK', 'Lawrence, KS', '  Silver Lake, KS   ', '  Berryville, AR   ', '  Cammack Village, AR   ', '  Chickasha, OK   ', '  Greenwood, MO   ', '  Webb City, MO   ', '  Gardner, KS   ', '  United States   (+25 others)   ', 'Fresno, CA', '  Atchison, KS   ', '  Lohman, MO   ', '  Fairview, MO   ', '  Edmond, OK   ', 'Eugene, MO', 'Higbee, MO', 'Chanute, KS', '  Bentley, KS   ', '  Liberty, MO   ', 'Shawnee, KS', '  Anthony, KS   ', '  Gracemont, OK   ', '  Westwood, MA   ', '  Lawrence, KS   ', 'Owasso, OK', '  Sand Springs, OK   ', '  Leavenworth, KS   ', 'North Kansas City, MO', '  Independence, KS   ', '  Alburtis, PA   ', '  St Robert, MO   ', 'Beloit, KS', '  Rolla, MO   ', 'Jenks, OK', 'Lincoln, MO', '  Midwest City, OK   ', '  Eastborough, KS   ', '  United States
# ...

# %%
state_code=[]
for place in unique_states :
    if isinstance(place, str):
        parts=place.split(",")
        if len(parts)>1:
            state_codes=parts[1].strip()
            state_code.append(state_codes)

print(state_code)
# Out:
# ['AR', 'AR', 'KS', 'MO', 'AR', 'MO', 'KS', 'OK', 'MO', 'AR', 'OK', 'KS', 'KS', 'AR', 'AR', 'OK', 'MO', 'MO', 'KS', 'CA', 'KS', 'MO', 'MO', 'OK', 'MO', 'MO', 'KS', 'KS', 'MO', 'KS', 'KS', 'OK', 'MA', 'KS', 'OK', 'OK', 'KS', 'MO', 'KS', 'PA', 'MO', 'KS', 'MO', 'OK', 'MO', 'OK', 'KS', 'AR', 'OK', 'OK', 'KS', 'MO', 'KS', 'MO', 'OK', 'OK', 'OK', 'KS', 'AR', 'CA', 'OK', 'MO', 'MO', 'MO', 'OK', 'OK', 'AR', 'CA', 'MO', 'NY', 'KS', 'MO', 'MO', 'OK', 'TX', 'MA', 'OK', 'MO', 'CA', 'OK', 'KS', 'MO', 'OK', 'AR', 'MO', 'AR', 'MO', 'OK', 'OK', 'KS', 'TX', 'MO', 'OK', 'MO', 'CA', 'MO', 'PA', 'MO', 'KS', 'KS', 'AR', 'MO', 'MO', 'CA', 'AR', 'MO', 'CA', 'MO', 'MO', 'MO', 'OK', 'AR', 'KS', 'KS', 'MO', 'AR', 'MO', 'OK', 'TX', 'MO', 'PA', 'MO', 'AR', 'MO', 'MO', 'KS', 'MO', 'CA', 'CA', 'AR', 'KS', 'KS   (+2 others)', 'MO', 'KS', 'OK', 'MO', 'KS   (+22 others)', 'KS', 'OK', 'OK', 'MO', 'KS', 'OK', 'OK', 'OK', 'MO', 'OK', 'OK', 'MO', 'OK', 'MO', 'KS', 'OK', 'MO', 'TX', 'MA', 'OK', 'MO', 'OK', 'KS', 'OK', 'K
# ...

# %%
#check what skills are the most demanding
skills_python=df[df['description_tokens'].str.contains('python')]
skills_sql=df[df['description_tokens'].str.contains('sql')]
skills_tableau=df[df['description_tokens'].str.contains('tableau')]
skills_power_bi=df[df['description_tokens'].str.contains('power_bi')]
python_frequency=skills_python.shape[0]
sql_frequency=skills_sql.shape[0]
tableau_frequency=skills_tableau.shape[0]
power_bi_frequency=skills_power_bi.shape[0]
plt.bar(['Python','SQL','Tableau','Power_BI'], [python_frequency, sql_frequency,tableau_frequency,power_bi_frequency])
plt.xlabel('Skills')
plt.ylabel('Frequency')
plt.title('Frequency of Skills in Job Descriptions')
plt.show()

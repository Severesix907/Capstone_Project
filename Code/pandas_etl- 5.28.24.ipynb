# %% [markdown]
# ## Extract
#
# Extract the data

# %%
import boto3
import pandas as pd
from io import StringIO

# create s3 client
s3 = boto3.client('s3')

# specify the bucket & folder you'd like to interact with
# will be using the cyber data as an example
name = "data-analyst-job-east"
file = "raw/gsearch_jobs.csv"

single_object = s3.get_object(Bucket=name, Key=file)
single_df = pd.read_csv(single_object['Body'])

# %%
single_df.head()
# Out:
#    Unnamed: 0  index                                              title  \
# 0           0      0                                       Data Analyst
# 1           1      1  Junior Data Analyst/Scientist Role - Contract ...
# 2           2      2                                       Data Analyst
# 3           3      3                                       Data Analyst
# 4           4      4                                       Data Analyst
#
#        company_name                location               via  \
# 0           Chloeta    Oklahoma City, OK     via ZipRecruiter
# 1            Upwork               Anywhere         via Upwork
# 2               ATC        United States         via LinkedIn
# 3        Guidehouse           Topeka, KS            via Nexxt
# 4  AnMed Health LLC               Anywhere       via LinkedIn
#
#                                          description  \
# 0  Job Summary: The Data Analyst oversees data pr...
# 1  Company\n\nThe TAC Index provides independent,...
# 2  Job Title: Entry Level Business Analyst / Prod...
# 3  Job Family :\n\nData Science & Analysis (Digit...
# 4  AnMed is a dynamic, comprehensive health syste...
#
#                                           extensions  \
# 0  ['21 hours ago', 'Full-time', 'Health insuranc...
# 1  ['17 hours ago', 'Work from home', 'Contractor...
# 2  ['12 hours ago', 'Full-time', 'Health insurance']
# 3  ['10 hours ago', 'Full-time', 'Health insuranc...
# 4  ['18 hours ago', 'Work from home', 'Part-time'...
#
#                                               job_id  \
# 0  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 1  eyJqb2JfdGl0bGUiOiJKdW5pb3IgRGF0YSBBbmFseXN0L1...
# 2  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 3  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 4  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
#
#                                            thumbnail  ... commute_time  \
# 0                                                NaN  ...          NaN
# 1                                                NaN  ...          NaN
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
# 4                                                NaN  ...          NaN
#
#   salary_pay salary_rate salary_avg salary_min salary_max salary_hourly  \
# 0        NaN         NaN        NaN        NaN        NaN           NaN
# 1        NaN         NaN        NaN        NaN        NaN           NaN
# 2        NaN         NaN        NaN        NaN        NaN           NaN
# 3        NaN         NaN        NaN        NaN        NaN           NaN
# 4        NaN         NaN        NaN        NaN        NaN           NaN
#
#    salary_yearly salary_standardized  \
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
#
#                                   description_tokens
# 0                                    ['python', 'r']
# 1  ['matlab', 'matplotlib', 'postgresql', 'mongod...
# 2                                                 []
# 3  ['powerpoint', 'perl', 'python', 'qlik', 'tabl...
# 4                                                 []
#
# [5 rows x 27 columns]

# %%
single_df['company_name'].value_counts()
# Out:
# company_name
# Upwork                             6934
# Talentify.io                       1683
# Walmart                            1537
# EDWARD JONES                        747
# Dice                                691
#                                    ...
# Fisher Financial  Advisors, LLC       1
# e-Emphasys Technologies               1
# The Marlin Alliance, Inc.             1
# Climate People                        1
# Techdash Telecom                      1
# Name: count, Length: 11019, dtype: int64

# %% [markdown]
# ## Transform

# %%
# 1) Drop staffing agencies (keywords to Staffing, Hire, Global, etc)

filtered_df = single_df[~single_df['company_name'].isin(['Upwork', 'Talentify.io'])]

company_counts = filtered_df['company_name'].value_counts()

# %%
filtered_df['company_name'].value_counts()
# Out:
# company_name
# Walmart               1537
# EDWARD JONES           747
# Dice                   691
# Corporate              612
# Cox Communications     538
#                       ...
# IDme                     1
# Teads                    1
# Jkbarnes                 1
# New Globe Inc            1
# Techdash Telecom         1
# Name: count, Length: 11017, dtype: int64

# %%
filtered_df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'title', 'company_name', 'location', 'via',
#        'description', 'extensions', 'job_id', 'thumbnail', 'posted_at',
#        'schedule_type', 'work_from_home', 'salary', 'search_term', 'date_time',
#        'search_location', 'commute_time', 'salary_pay', 'salary_rate',
#        'salary_avg', 'salary_min', 'salary_max', 'salary_hourly',
#        'salary_yearly', 'salary_standardized', 'description_tokens'],
#       dtype='object')

# %%
# 2) Most important columns: description_token, salary_standardized, title, date_time   (drop everything else)

selected_columns_df = filtered_df[['description_tokens', 'salary_standardized', 'title', 'date_time']]
selected_columns_df
# Out:
#                                       description_tokens  salary_standardized  \
# 0                                        ['python', 'r']                  NaN
# 2                                                     []                  NaN
# 3      ['powerpoint', 'perl', 'python', 'qlik', 'tabl...                  NaN
# 4                                                     []                  NaN
# 5                                                     []                  NaN
# ...                                                  ...                  ...
# 48392  ['python', 'sql', 'tableau', 'snowflake', 'r',...             103781.0
# 48393                                                 []             144481.5
# 48394                                                 []             144481.5
# 48395                                                 []             144481.5
# 48396                              ['cognos', 'tableau']             132315.0
#
#                                                    title  \
# 0                                           Data Analyst
# 2                                           Data Analyst
# 3                                           Data Analyst
# 4                                           Data Analyst
# 5                                Research Data Analyst 1
# ...                                                  ...
# 48392                     Marketing Data & BI Analyst II
# 48393                                  Lead-Data Analyst
# 48394                                  Lead-Data Analyst
# 48395                                  Lead-Data Analyst
# 48396  Institutional Credit Management - Lending Data...
#
#                         date_time
# 0      2023-08-03 03:00:09.849838
# 2      2023-08-03 03:00:09.849838
# 3      2023-08-03 03:00:09.849838
# 4      2023-08-03 03:00:09.849838
# 5      2023-08-03 03:00:09.849838
# ...                           ...
# 48392  2022-11-04 03:40:23.706734
# 48393  2022-11-24 04:00:08.710801
# 48394  2022-12-07 04:00:12.563831
# 48395  2022-12-08 04:00:15.975728
# 48396  2023-01-25 04:00:26.521124
#
# [39780 rows x 4 columns]

# %%
# 3) drop 39,000 missing rows of salary_standardized

selected_columns_df.isnull().sum()
# Out:
# description_tokens         0
# salary_standardized    34845
# title                      0
# date_time                  0
# dtype: int64

# %%
selected_columns_df = selected_columns_df.dropna(subset=['salary_standardized'])
selected_columns_df
# Out:
#                                       description_tokens  salary_standardized  \
# 19                          ['pl/sql', 'sql', 'tableau']              94640.0
# 29                                                    []              48391.2
# 96                                ['python', 'sql', 'r']              86320.0
# 98                     ['python', 'sql', 'r', 'tableau']             122000.0
# 102           ['powerpoint', 'word', 'excel', 'outlook']             100000.0
# ...                                                  ...                  ...
# 48392  ['python', 'sql', 'tableau', 'snowflake', 'r',...             103781.0
# 48393                                                 []             144481.5
# 48394                                                 []             144481.5
# 48395                                                 []             144481.5
# 48396                              ['cognos', 'tableau']             132315.0
#
#                                                    title  \
# 19     Data Analyst Report Writer (Level 2) _ Austin,...
# 29      Associate Research/Data Analyst-CES - Now Hiring
# 96     Bioinformatics Analyst (NGS/OMICS/SQL/Curation...
# 98                                          Data Analyst
# 102                  Data Analyst | Workforce Management
# ...                                                  ...
# 48392                     Marketing Data & BI Analyst II
# 48393                                  Lead-Data Analyst
# 48394                                  Lead-Data Analyst
# 48395                                  Lead-Data Analyst
# 48396  Institutional Credit Management - Lending Data...
#
#                         date_time
# 19     2023-08-03 03:00:11.064921
# 29     2023-08-03 03:00:13.367401
# 96     2023-08-03 03:01:00.649092
# 98     2023-08-04 03:00:13.797776
# 102    2023-08-04 03:00:13.797776
# ...                           ...
# 48392  2022-11-04 03:40:23.706734
# 48393  2022-11-24 04:00:08.710801
# 48394  2022-12-07 04:00:12.563831
# 48395  2022-12-08 04:00:15.975728
# 48396  2023-01-25 04:00:26.521124
#
# [4935 rows x 4 columns]

# %%
# 4) join in the missing data

# %%
import boto3
import pandas as pd
from io import StringIO

# create s3 client
s3 = boto3.client('s3')

# specify the bucket & folder you'd like to interact with
# will be using the cyber data as an example
name = "data-analyst-job-east"
file = "raw/LinkedIn_job_list.csv"

Second_object = s3.get_object(Bucket=name, Key=file)
Second_df = pd.read_csv(Second_object['Body'])

# %%
Second_df.head()
# Out:
#                               job_title       company_name time_posted  \
# 0  Data Scientist, Small Business Group               Meta   1 day ago
# 1                 Junior Data Scientist  Team Remotely Inc   1 day ago
# 2                     ML Engineer-AI/ML  Zortech Solutions   1 day ago
# 3             Data Scientist, Analytics           DoorDash         NaN
# 4                 Junior Data Scientist        LTIMindtree         NaN
#
#    num_applicants employment_type  \
# 0   77 applicants  Not Applicable
# 1  100 applicants     Entry level
# 2   49 applicants     Entry level
# 3             NaN     Entry level
# 4             NaN     Entry level
#
#                                               salary
# 0  Base pay range\r\n\r\n      $134,000.00/yr - $...
# 1                                                NaN
# 2                                                NaN
# 3  Base pay range\r\n\r\n      $133,000.00/yr - $...
# 4                                                NaN

# %%
Second_df = Second_df.rename(columns={'job_title': 'title'})

# %%
import re

# %%
def extract_average_salary(salary_range):
    if isinstance(salary_range, str):
        salaries = re.findall(r'\$\d{1,3}(?:,\d{3})*(?:\.\d{2})?', salary_range)
        salaries = [float(s.replace('$', '').replace(',', '')) for s in salaries]
        if salaries:
            return sum(salaries) / len(salaries)
    return None
Second_df['average_salary'] = Second_df['salary'].apply(extract_average_salary)
Second_df = Second_df.dropna(subset=['average_salary'])
overall_average_salary = Second_df['average_salary'].mean()

# %%
Second_df
# Out:
#                                                  title    company_name  \
# 0                 Data Scientist, Small Business Group            Meta
# 3                            Data Scientist, Analytics        DoorDash
# 5                            Data Scientist, Analytics        DoorDash
# 7                                    Jr Data Scientist           EVONA
# 9                            Data Scientist, Analytics        DoorDash
# ..                                                 ...             ...
# 333                                   Business Analyst  Insight Global
# 335                              Senior Data Scientist    Qventus, Inc
# 338                              Staff, Data Scientist         Walmart
# 344                           Business Systems Analyst        Vernovis
# 346  Are you a Document Administrator looking for c...  eStaffing Inc.
#
#      time_posted  num_applicants   employment_type  \
# 0      1 day ago   77 applicants    Not Applicable
# 3            NaN             NaN       Entry level
# 5            NaN             NaN       Entry level
# 7            NaN             NaN       Entry level
# 9            NaN             NaN       Entry level
# ..           ...             ...               ...
# 333          NaN  149 applicants  Mid-Senior level
# 335          NaN  111 applicants  Mid-Senior level
# 338   5 days ago             NaN       Entry level
# 344          NaN   78 applicants  Mid-Senior level
# 346  3 weeks ago             NaN       Entry level
#
#                                                 salary  average_salary
# 0    Base pay range\r\n\r\n      $134,000.00/yr - $...        169000.0
# 3    Base pay range\r\n\r\n      $133,000.00/yr - $...        188000.0
# 5    Base pay range\r\n\r\n      $133,000.00/yr - $...        188000.0
# 7    Base pay range\r\n\r\n      $100,000.00/yr - $...        110000.0
# 9    Base pay range\r\n\r\n      $133,000.00/yr - $...        188000.0
# ..                                                 ...             ...
# 333  Base pay range\r\n\r\n      $38.00/hr - $50.00/hr            44.0
# 335  Base pay range\r\n\r\n      $170,000.00/yr - $...        180000.0
# 338  Base pay range\r\n\r\n      $143,000.00/yr - $...        214500.0
# 344  Base pay range\r\n\r\n      $110,000.00/yr - $...        112500.0
# 346  Base pay range\r\n\r\n      $40.00/hr - $60.00/hr            50.0
#
# [109 rows x 7 columns]

# %%
# Combine the dataframes
combined_df = pd.concat([single_df, Second_df], ignore_index=True)

# %%
combined_df
# Out:
#        Unnamed: 0  index                                              title  \
# 0             0.0    0.0                                       Data Analyst
# 1             1.0    1.0  Junior Data Analyst/Scientist Role - Contract ...
# 2             2.0    2.0                                       Data Analyst
# 3             3.0    3.0                                       Data Analyst
# 4             4.0    4.0                                       Data Analyst
# ...           ...    ...                                                ...
# 48501         NaN    NaN                                   Business Analyst
# 48502         NaN    NaN                              Senior Data Scientist
# 48503         NaN    NaN                              Staff, Data Scientist
# 48504         NaN    NaN                           Business Systems Analyst
# 48505         NaN    NaN  Are you a Document Administrator looking for c...
#
#            company_name                location               via  \
# 0               Chloeta    Oklahoma City, OK     via ZipRecruiter
# 1                Upwork               Anywhere         via Upwork
# 2                   ATC        United States         via LinkedIn
# 3            Guidehouse           Topeka, KS            via Nexxt
# 4      AnMed Health LLC               Anywhere       via LinkedIn
# ...                 ...                     ...               ...
# 48501    Insight Global                     NaN               NaN
# 48502      Qventus, Inc                     NaN               NaN
# 48503           Walmart                     NaN               NaN
# 48504          Vernovis                     NaN               NaN
# 48505    eStaffing Inc.                     NaN               NaN
#
#                                              description  \
# 0      Job Summary: The Data Analyst oversees data pr...
# 1      Company\n\nThe TAC Index provides independent,...
# 2      Job Title: Entry Level Business Analyst / Prod...
# 3      Job Family :\n\nData Science & Analysis (Digit...
# 4      AnMed is a dynamic, comprehensive health syste...
# ...                                                  ...
# 48501                                                NaN
# 48502                                                NaN
# 48503                                                NaN
# 48504                                                NaN
# 48505                                                NaN
#
#                                               extensions  \
# 0      ['21 hours ago', 'Full-time', 'Health insuranc...
# 1      ['17 hours ago', 'Work from home', 'Contractor...
# 2      ['12 hours ago', 'Full-time', 'Health insurance']
# 3      ['10 hours ago', 'Full-time', 'Health insuranc...
# 4      ['18 hours ago', 'Work from home', 'Part-time'...
# ...                                                  ...
# 48501                                                NaN
# 48502                                                NaN
# 48503                                                NaN
# 48504                                                NaN
# 48505                                                NaN
#
#                                                   job_id  \
# 0      eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 1      eyJqb2JfdGl0bGUiOiJKdW5pb3IgRGF0YSBBbmFseXN0L1...
# 2      eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 3      eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 4      eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# ...                                                  ...
# 48501                                                NaN
# 48502                                                NaN
# 48503                                                NaN
# 48504                                                NaN
# 48505                                                NaN
#
#                                                thumbnail  ... salary_min  \
# 0                                                    NaN  ...        NaN
# 1                                                    NaN  ...        NaN
# 2      https://encrypted-tbn0.gstatic.com/images?q=tb...  ...        NaN
# 3      https://encrypted-tbn0.gstatic.com/images?q=tb...  ...        NaN
# 4                                                    NaN  ...        NaN
# ...                                                  ...  ...        ...
# 48501                                                NaN  ...        NaN
# 48502                                                NaN  ...        NaN
# 48503                                                NaN  ...        NaN
# 48504                                                NaN  ...        NaN
# 48505                                                NaN  ...        NaN
#
#       salary_max salary_hourly salary_yearly salary_standardized  \
# 0            NaN           NaN           NaN                 NaN
# 1            NaN           NaN           NaN                 NaN
# 2            NaN           NaN           NaN                 NaN
# 3            NaN           NaN           NaN                 NaN
# 4            NaN           NaN           NaN                 NaN
# ...          ...           ...           ...                 ...
# 48501        NaN           NaN           NaN                 NaN
# 48502        NaN           NaN           NaN                 NaN
# 48503        NaN           NaN           NaN                 NaN
# 48504        NaN           NaN           NaN                 NaN
# 48505        NaN           NaN           NaN                 NaN
#
#                                       description_tokens  time_posted  \
# 0                                        ['python', 'r']          NaN
# 1      ['matlab', 'matplotlib', 'postgresql', 'mongod...          NaN
# 2                                                     []          NaN
# 3      ['powerpoint', 'perl', 'python', 'qlik', 'tabl...          NaN
# 4                                                     []          NaN
# ...                                                  ...          ...
# 48501                                                NaN          NaN
# 48502                                                NaN          NaN
# 48503                                                NaN   5 days ago
# 48504                                                NaN          NaN
# 48505                                                NaN  3 weeks ago
#
#        num_applicants   employment_type average_salary
# 0                 NaN               NaN            NaN
# 1                 NaN               NaN            NaN
# 2                 NaN               NaN            NaN
# 3                 NaN               NaN            NaN
# 4                 NaN               NaN            NaN
# ...               ...               ...            ...
# 48501  149 applicants  Mid-Senior level           44.0
# 48502  111 applicants  Mid-Senior level       180000.0
# 48503             NaN       Entry level       214500.0
# 48504   78 applicants  Mid-Senior level       112500.0
# 48505             NaN       Entry level           50.0
#
# [48506 rows x 31 columns]

# %% [markdown]
# ## Load

# %%
# 5) Load data back into s3 bucket
import boto3

# open client
client = boto3.client('s3')

# some initial variables
bucket_name = "test-ds2024-bucket"

# open the file in binary format, and save into the var 'data'
with open("data/Tux.svg.png", "rb") as f:
    data = f.read()

### ADDING OBJECTS TO A BUCKET ###
response = client.put_object(
    Body=data,
    Bucket=bucket_name,
    Key="tux-image"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 11
#       8 bucket_name = "test-ds2024-bucket"
#      10 # open the file in binary format, and save into the var 'data'
# ---> 11 with open("data/Tux.svg.png", "rb") as f:
#      12     data = f.read()
#      14 ### ADDING OBJECTS TO A BUCKET ###
#
# File c:\Users\xiaoj\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Tux.svg.png'

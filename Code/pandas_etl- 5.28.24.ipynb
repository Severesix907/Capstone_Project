# %% [markdown]
# ## Extract
#
# Extract the data

# %%
import boto3
import pandas as pd
from io import StringIO

# create s3 client
s3 = boto3.client('s3')

# specify the bucket & folder you'd like to interact with
# will be using the cyber data as an example
name = "data-analyst-job-east"
file = "raw/gsearch_jobs.csv"

single_object = s3.get_object(Bucket=name, Key=file)
single_df = pd.read_csv(single_object['Body'])

# %%
single_df.head()
# Out:
#    Unnamed: 0  index                                              title  \
# 0           0      0                                       Data Analyst
# 1           1      1  Junior Data Analyst/Scientist Role - Contract ...
# 2           2      2                                       Data Analyst
# 3           3      3                                       Data Analyst
# 4           4      4                                       Data Analyst
#
#        company_name                location               via  \
# 0           Chloeta    Oklahoma City, OK     via ZipRecruiter
# 1            Upwork               Anywhere         via Upwork
# 2               ATC        United States         via LinkedIn
# 3        Guidehouse           Topeka, KS            via Nexxt
# 4  AnMed Health LLC               Anywhere       via LinkedIn
#
#                                          description  \
# 0  Job Summary: The Data Analyst oversees data pr...
# 1  Company\n\nThe TAC Index provides independent,...
# 2  Job Title: Entry Level Business Analyst / Prod...
# 3  Job Family :\n\nData Science & Analysis (Digit...
# 4  AnMed is a dynamic, comprehensive health syste...
#
#                                           extensions  \
# 0  ['21 hours ago', 'Full-time', 'Health insuranc...
# 1  ['17 hours ago', 'Work from home', 'Contractor...
# 2  ['12 hours ago', 'Full-time', 'Health insurance']
# 3  ['10 hours ago', 'Full-time', 'Health insuranc...
# 4  ['18 hours ago', 'Work from home', 'Part-time'...
#
#                                               job_id  \
# 0  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 1  eyJqb2JfdGl0bGUiOiJKdW5pb3IgRGF0YSBBbmFseXN0L1...
# 2  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 3  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 4  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
#
#                                            thumbnail  ... commute_time  \
# 0                                                NaN  ...          NaN
# 1                                                NaN  ...          NaN
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
# 4                                                NaN  ...          NaN
#
#   salary_pay salary_rate salary_avg salary_min salary_max salary_hourly  \
# 0        NaN         NaN        NaN        NaN        NaN           NaN
# 1        NaN         NaN        NaN        NaN        NaN           NaN
# 2        NaN         NaN        NaN        NaN        NaN           NaN
# 3        NaN         NaN        NaN        NaN        NaN           NaN
# 4        NaN         NaN        NaN        NaN        NaN           NaN
#
#    salary_yearly salary_standardized  \
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
#
#                                   description_tokens
# 0                                    ['python', 'r']
# 1  ['matlab', 'matplotlib', 'postgresql', 'mongod...
# 2                                                 []
# 3  ['powerpoint', 'perl', 'python', 'qlik', 'tabl...
# 4                                                 []
#
# [5 rows x 27 columns]

# %%
single_df['company_name'].value_counts()
# Out:
# company_name
# Upwork                             6934
# Talentify.io                       1683
# Walmart                            1537
# EDWARD JONES                        747
# Dice                                691
#                                    ...
# Fisher Financial  Advisors, LLC       1
# e-Emphasys Technologies               1
# The Marlin Alliance, Inc.             1
# Climate People                        1
# Techdash Telecom                      1
# Name: count, Length: 11019, dtype: int64

# %% [markdown]
# ## Transform

# %%
# 1) Drop staffing agencies (keywords to Staffing, Hire, Global, etc)

filtered_df = single_df[~single_df['company_name'].isin(['Upwork', 'Talentify.io'])]

company_counts = filtered_df['company_name'].value_counts()

# %%
filtered_df['company_name'].value_counts()
# Out:
# company_name
# Walmart               1537
# EDWARD JONES           747
# Dice                   691
# Corporate              612
# Cox Communications     538
#                       ...
# IDme                     1
# Teads                    1
# Jkbarnes                 1
# New Globe Inc            1
# Techdash Telecom         1
# Name: count, Length: 11017, dtype: int64

# %%
filtered_df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'title', 'company_name', 'location', 'via',
#        'description', 'extensions', 'job_id', 'thumbnail', 'posted_at',
#        'schedule_type', 'work_from_home', 'salary', 'search_term', 'date_time',
#        'search_location', 'commute_time', 'salary_pay', 'salary_rate',
#        'salary_avg', 'salary_min', 'salary_max', 'salary_hourly',
#        'salary_yearly', 'salary_standardized', 'description_tokens'],
#       dtype='object')

# %%
# 2) Most important columns: description_token, salary_standardized, title, date_time   (drop everything else)

selected_columns_df = filtered_df[['description_tokens', 'salary_standardized', 'title', 'date_time','company_name']]
selected_columns_df
# Out:
#                                       description_tokens  salary_standardized  \
# 0                                        ['python', 'r']                  NaN
# 2                                                     []                  NaN
# 3      ['powerpoint', 'perl', 'python', 'qlik', 'tabl...                  NaN
# 4                                                     []                  NaN
# 5                                                     []                  NaN
# ...                                                  ...                  ...
# 48392  ['python', 'sql', 'tableau', 'snowflake', 'r',...             103781.0
# 48393                                                 []             144481.5
# 48394                                                 []             144481.5
# 48395                                                 []             144481.5
# 48396                              ['cognos', 'tableau']             132315.0
#
#                                                    title  \
# 0                                           Data Analyst
# 2                                           Data Analyst
# 3                                           Data Analyst
# 4                                           Data Analyst
# 5                                Research Data Analyst 1
# ...                                                  ...
# 48392                     Marketing Data & BI Analyst II
# 48393                                  Lead-Data Analyst
# 48394                                  Lead-Data Analyst
# 48395                                  Lead-Data Analyst
# 48396  Institutional Credit Management - Lending Data...
#
#                         date_time                        company_name
# 0      2023-08-03 03:00:09.849838                             Chloeta
# 2      2023-08-03 03:00:09.849838                                 ATC
# 3      2023-08-03 03:00:09.849838                          Guidehouse
# 4      2023-08-03 03:00:09.849838                    AnMed Health LLC
# 5      2023-08-03 03:00:09.849838  Oregon Health & Science University
# ...                           ...                                 ...
# 48392  2022-11-04 03:40:23.706734                        EDWARD JONES
# 48393  2022-11-24 04:00:08.710801                        EDWARD JONES
# 48394  2022-12-07 04:00:12.563831                        EDWARD JONES
# 48395  2022-12-08 04:00:15.975728                        EDWARD JONES
# 48396  2023-01-25 04:00:26.521124                                Citi
#
# [39780 rows x 5 columns]

# %%
# 3) drop 39,000 missing rows of salary_standardized

selected_columns_df.isnull().sum()
# Out:
# description_tokens         0
# salary_standardized    34845
# title                      0
# date_time                  0
# company_name               0
# dtype: int64

# %%
selected_columns_df = selected_columns_df.dropna(subset=['salary_standardized'])
selected_columns_df
# Out:
#                                       description_tokens  salary_standardized  \
# 19                          ['pl/sql', 'sql', 'tableau']              94640.0
# 29                                                    []              48391.2
# 96                                ['python', 'sql', 'r']              86320.0
# 98                     ['python', 'sql', 'r', 'tableau']             122000.0
# 102           ['powerpoint', 'word', 'excel', 'outlook']             100000.0
# ...                                                  ...                  ...
# 48392  ['python', 'sql', 'tableau', 'snowflake', 'r',...             103781.0
# 48393                                                 []             144481.5
# 48394                                                 []             144481.5
# 48395                                                 []             144481.5
# 48396                              ['cognos', 'tableau']             132315.0
#
#                                                    title  \
# 19     Data Analyst Report Writer (Level 2) _ Austin,...
# 29      Associate Research/Data Analyst-CES - Now Hiring
# 96     Bioinformatics Analyst (NGS/OMICS/SQL/Curation...
# 98                                          Data Analyst
# 102                  Data Analyst | Workforce Management
# ...                                                  ...
# 48392                     Marketing Data & BI Analyst II
# 48393                                  Lead-Data Analyst
# 48394                                  Lead-Data Analyst
# 48395                                  Lead-Data Analyst
# 48396  Institutional Credit Management - Lending Data...
#
#                         date_time                      company_name
# 19     2023-08-03 03:00:11.064921                      OQ Point LLC
# 29     2023-08-03 03:00:13.367401  Saint Louis County Clerks Office
# 96     2023-08-03 03:01:00.649092                            Rangam
# 98     2023-08-04 03:00:13.797776                              Meta
# 102    2023-08-04 03:00:13.797776                      Krispy Kreme
# ...                           ...                               ...
# 48392  2022-11-04 03:40:23.706734                      EDWARD JONES
# 48393  2022-11-24 04:00:08.710801                      EDWARD JONES
# 48394  2022-12-07 04:00:12.563831                      EDWARD JONES
# 48395  2022-12-08 04:00:15.975728                      EDWARD JONES
# 48396  2023-01-25 04:00:26.521124                              Citi
#
# [4935 rows x 5 columns]

# %%
# 4) join in the missing data

# %%
import boto3
import pandas as pd
from io import StringIO

# create s3 client
s3 = boto3.client('s3')

# specify the bucket & folder you'd like to interact with
# will be using the cyber data as an example
name = "data-analyst-job-east"
file = "raw/LinkedIn_Clean_List.csv"

Second_object = s3.get_object(Bucket=name, Key=file)
Second_df = pd.read_csv(Second_object['Body'])

# %%
Second_df.head()
# Out:
#                                  Title    Company      Posted  Applicants  \
# 0  data scientist small business group       Meta   1 day ago          77
# 1             data scientist analytics   DoorDash   1 day ago           0
# 2                       data scientist  Walgreens   1 day ago         170
# 3                    jr data scientist      EVONA   1 day ago           0
# 4                  data science intern  ActiGraph  6 days ago           0
#
#              Type     Salary  Data Science  Machine Learning  Data Analyst
# 0  Not Applicable  169000.00          True             False         False
# 1     Entry level  188000.00          True             False         False
# 2  Not Applicable  119324.07          True             False         False
# 3     Entry level  110000.00          True             False         False
# 4      Internship   39088.40          True             False         False

# %%
Second_df = Second_df.rename(columns={'Company': 'company_name'})

# %%
Second_df = Second_df.rename(columns={'Title': 'title'})

# %%
#https://medium.com/codex/data-cleaning-using-pandas-c65e20a84c4b

# %%
Second_df
# Out:
#                                    title company_name      Posted  Applicants  \
# 0    data scientist small business group         Meta   1 day ago          77
# 1               data scientist analytics     DoorDash   1 day ago           0
# 2                         data scientist    Walgreens   1 day ago         170
# 3                      jr data scientist        EVONA   1 day ago           0
# 4                    data science intern    ActiGraph  6 days ago           0
# ..                                   ...          ...         ...         ...
# 219                       safety analyst        VDart   1 day ago           0
# 220                 staff data scientist      Walmart  5 days ago           0
# 221                        fraud analyst       Newegg   1 day ago          37
# 222                 ai software engineer         Zoom   1 day ago           0
# 223        data and analytics specialist          UBS  6 days ago           0
#
#                  Type     Salary  Data Science  Machine Learning  Data Analyst
# 0      Not Applicable  169000.00          True             False         False
# 1         Entry level  188000.00          True             False         False
# 2      Not Applicable  119324.07          True             False         False
# 3         Entry level  110000.00          True             False         False
# 4          Internship   39088.40          True             False         False
# ..                ...        ...           ...               ...           ...
# 219  Mid-Senior level  118502.52         False             False         False
# 220       Entry level  214500.00          True             False         False
# 221  Mid-Senior level  118502.52         False             False         False
# 222    Not Applicable  119324.07         False              True         False
# 223    Not Applicable  119324.07         False             False         False
#
# [224 rows x 9 columns]

# %%
#Second_df = Second_df.rename(columns={'average_salary': 'salary_standardized'})

# %%
Second_df = filtered_df[['title', 'company_name']]
Second_df
# Out:
#                                                    title  \
# 0                                           Data Analyst
# 2                                           Data Analyst
# 3                                           Data Analyst
# 4                                           Data Analyst
# 5                                Research Data Analyst 1
# ...                                                  ...
# 48392                     Marketing Data & BI Analyst II
# 48393                                  Lead-Data Analyst
# 48394                                  Lead-Data Analyst
# 48395                                  Lead-Data Analyst
# 48396  Institutional Credit Management - Lending Data...
#
#                              company_name
# 0                                 Chloeta
# 2                                     ATC
# 3                              Guidehouse
# 4                        AnMed Health LLC
# 5      Oregon Health & Science University
# ...                                   ...
# 48392                        EDWARD JONES
# 48393                        EDWARD JONES
# 48394                        EDWARD JONES
# 48395                        EDWARD JONES
# 48396                                Citi
#
# [39780 rows x 2 columns]

# %%
# Combine the dataframes
combined_df = pd.concat([selected_columns_df, Second_df], ignore_index=True)

# %%
combined_df
# Out:
#                                description_tokens  salary_standardized  \
# 0                    ['pl/sql', 'sql', 'tableau']              94640.0
# 1                                              []              48391.2
# 2                          ['python', 'sql', 'r']              86320.0
# 3               ['python', 'sql', 'r', 'tableau']             122000.0
# 4      ['powerpoint', 'word', 'excel', 'outlook']             100000.0
# ...                                           ...                  ...
# 44710                                         NaN                  NaN
# 44711                                         NaN                  NaN
# 44712                                         NaN                  NaN
# 44713                                         NaN                  NaN
# 44714                                         NaN                  NaN
#
#                                                    title  \
# 0      Data Analyst Report Writer (Level 2) _ Austin,...
# 1       Associate Research/Data Analyst-CES - Now Hiring
# 2      Bioinformatics Analyst (NGS/OMICS/SQL/Curation...
# 3                                           Data Analyst
# 4                    Data Analyst | Workforce Management
# ...                                                  ...
# 44710                     Marketing Data & BI Analyst II
# 44711                                  Lead-Data Analyst
# 44712                                  Lead-Data Analyst
# 44713                                  Lead-Data Analyst
# 44714  Institutional Credit Management - Lending Data...
#
#                         date_time                      company_name
# 0      2023-08-03 03:00:11.064921                      OQ Point LLC
# 1      2023-08-03 03:00:13.367401  Saint Louis County Clerks Office
# 2      2023-08-03 03:01:00.649092                            Rangam
# 3      2023-08-04 03:00:13.797776                              Meta
# 4      2023-08-04 03:00:13.797776                      Krispy Kreme
# ...                           ...                               ...
# 44710                         NaN                      EDWARD JONES
# 44711                         NaN                      EDWARD JONES
# 44712                         NaN                      EDWARD JONES
# 44713                         NaN                      EDWARD JONES
# 44714                         NaN                              Citi
#
# [44715 rows x 5 columns]

# %%
# I still need to EDA Analysis for the Combined data

# %%
combined_df.to_csv('output.csv', index=False)

# %% [markdown]
# ## Load

# %%
# 5) Load data back into s3 bucket
import boto3

# open client
client = boto3.client('s3')

# some initial variables
bucket_name = "data-analyst-job-east"
object_key = "transformed/combined_data.csv"

# open the file in binary format, and save into the var 'data'
with open("output.csv", "rb") as f:
    data = f.read()

### ADDING OBJECTS TO A BUCKET ###
response = client.put_object(
    Body=data,
    Bucket=bucket_name,
    Key=object_key
)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# pd.set_option('max_columns', 200)

# %%
df = pd.read_csv("../p_code/gsearch_jobs.csv",  usecols=['title','company_name', 'date_time', 'location', 'via', 'description', 'extensions', 'commute_time', 'salary_pay', 'salary_rate', 'salary_avg', 'salary_min', 'salary_max', 'salary_hourly', 'salary_yearly', 'salary_standardized'])
df
# Out:
#                                                    title      company_name  \
# 0                                           Data Analyst           Chloeta
# 1      Junior Data Analyst/Scientist Role - Contract ...            Upwork
# 2                                           Data Analyst               ATC
# 3                                           Data Analyst        Guidehouse
# 4                                           Data Analyst  AnMed Health LLC
# ...                                                  ...               ...
# 48392                     Marketing Data & BI Analyst II      EDWARD JONES
# 48393                                  Lead-Data Analyst      EDWARD JONES
# 48394                                  Lead-Data Analyst      EDWARD JONES
# 48395                                  Lead-Data Analyst      EDWARD JONES
# 48396  Institutional Credit Management - Lending Data...              Citi
#
#                      location                    via  \
# ...

# %%
#Check memory usage and the datatype of each column
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48397 entries, 0 to 48396
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                48397 non-null  object
#  1   company_name         48397 non-null  object
#  2   location             48362 non-null  object
#  3   via                  48388 non-null  object
#  4   description          48397 non-null  object
#  5   extensions           48397 non-null  object
#  6   date_time            48397 non-null  object
#  7   commute_time         0 non-null      float64
#  8   salary_pay           8300 non-null   object
#  9   salary_rate          8300 non-null   object
#  10  salary_avg           8300 non-null   float64
#  11  salary_min           7845 non-null   float64
#  12  salary_max           7845 non-null   float64
#  13  salary_hourly        5210 non-null   float64
#  14  salary_yearly        3063 non-null   float64
# ...

# %%
#Provided information about the overall rows and colums.
df.shape
# Out:
# (48397, 16)

# %%
# Shows the first five rolls of the dataset
df.head(20)
# Out:
#                                                 title  \
# 0                                        Data Analyst
# 1   Junior Data Analyst/Scientist Role - Contract ...
# 2                                        Data Analyst
# 3                                        Data Analyst
# 4                                        Data Analyst
# 5                             Research Data Analyst 1
# 6                                        Data Analyst
# 7                                        Data Analyst
# 8                             Healthcare Data Analyst
# 9                                        Data Analyst
# 10                             Associate Data Analyst
# 11             Data Growth Analyst & Insights Manager
# 12              Data Analyst I (Healthcare Analytics)
# 13                  Data Scientist - Contract to hire
# 14                                Senior Data Analyst
# 15                                    Sr Data Analyst
# ...

# %%
# List all the columns
df.columns
# Out:
# Index(['title', 'company_name', 'location', 'via', 'description', 'extensions',
#        'date_time', 'commute_time', 'salary_pay', 'salary_rate', 'salary_avg',
#        'salary_min', 'salary_max', 'salary_hourly', 'salary_yearly',
#        'salary_standardized'],
#       dtype='object')

# %%
# Displays the data types of each column
df.dtypes
# Out:
# title                   object
# company_name            object
# location                object
# via                     object
# description             object
# extensions              object
# date_time               object
# commute_time           float64
# salary_pay              object
# salary_rate             object
# salary_avg             float64
# salary_min             float64
# salary_max             float64
# salary_hourly          float64
# salary_yearly          float64
# salary_standardized    float64
# dtype: object

# %%
#The 'date_time' column needed to be change from an objet to a datetime64[ns] object. 
# pd.to_datetime(df['date_time'])
df['date_time'] = pd.to_datetime(df['date_time'])

# %%
#Shows the statistics of all columns
df.describe()
# Out:
#                            date_time  commute_time     salary_avg  \
# count                          48397           0.0    8300.000000
# mean   2023-07-23 11:34:17.987608576           NaN   37724.512387
# min       2022-11-04 03:40:11.151943           NaN       7.250000
# 25%    2023-03-02 04:00:21.450978048           NaN      30.500000
# 50%    2023-07-27 03:00:44.901114880           NaN      57.500000
# 75%    2023-11-27 04:00:24.028146944           NaN   87725.000000
# max       2024-05-14 03:00:39.311531           NaN  300000.000000
# std                              NaN           NaN   53040.963321
#
#           salary_min     salary_max  salary_hourly  salary_yearly  \
# count    7845.000000    7845.000000    5210.000000    3063.000000
# mean    31305.770416   44781.575437      41.066887  102088.459110
# min         8.000000      10.000000       7.250000   29289.840000
# 25%        18.460000      44.000000      23.500000   80000.000000
# ...

# %%
df.sort_values(by="date_time", ascending=True).head(20)
# Out:
#                                                    title  \
# 30868                                   Sr. Data Analyst
# 48136                                    Data Analyst II
# 29868                Data Analyst III - Full Time - Days
# 48070              DATA ANALYST w/INFORMATICA EXPERIENCE
# 45152                           Data Analyst / Analytics
# 36588                                       Data Analyst
# 38565                                     Data Analyst I
# 30866                          Sr. Business Data Analyst
# 38309                    Data Analyst - Finance (Remote)
# 43216                                       Data Analyst
# 38296                              Data Analyst (Remote)
# 30457  Product Information Management (PIM) Data Analyst
# 44095                                       Data Analyst
# 31589                        Data Analyst, Forbes Vetted
# 34993                                Data Analyst Needed
# ...

# %%
sns.histplot(data=df, x="salary_min", y="salary_max")
# Out:
# /Users/pcordero/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/pcordero/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='salary_min', ylabel='salary_max'>

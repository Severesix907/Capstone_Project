# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/pcordero/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("../p_code/gsearch_jobs.csv",  usecols=['title','company_name', 'date_time', 'location', 'via', 'description', 'extensions', 'commute_time', 'salary_pay', 'salary_rate', 'salary_avg', 'salary_min', 'salary_max', 'salary_hourly', 'salary_yearly', 'salary_standardized'])
df
# Out:
#                                                    title      company_name  \
# 0                                           Data Analyst           Chloeta
# 1      Junior Data Analyst/Scientist Role - Contract ...            Upwork
# 2                                           Data Analyst               ATC
# 3                                           Data Analyst        Guidehouse
# 4                                           Data Analyst  AnMed Health LLC
# ...                                                  ...               ...
# 48392                     Marketing Data & BI Analyst II      EDWARD JONES
# 48393                                  Lead-Data Analyst      EDWARD JONES
# 48394                                  Lead-Data Analyst      EDWARD JONES
# 48395                                  Lead-Data Analyst      EDWARD JONES
# 48396  Institutional Credit Management - Lending Data...              Citi
#
#                      location                    via  \
# 0        Oklahoma City, OK          via ZipRecruiter
# 1                   Anywhere              via Upwork
# 2            United States              via LinkedIn
# 3               Topeka, KS                 via Nexxt
# 4                   Anywhere            via LinkedIn
# ...                       ...                    ...
# 48392           Houstonia, MO  via My ArkLaMiss Jobs
# 48393          Marshfield, MO  via My ArkLaMiss Jobs
# 48394          High Point, MO  via My ArkLaMiss Jobs
# 48395             Calhoun, MO  via My ArkLaMiss Jobs
# 48396           United States  via My ArkLaMiss Jobs
#
#                                              description  \
# 0      Job Summary: The Data Analyst oversees data pr...
# 1      Company\n\nThe TAC Index provides independent,...
# 2      Job Title: Entry Level Business Analyst / Prod...
# 3      Job Family :\n\nData Science & Analysis (Digit...
# 4      AnMed is a dynamic, comprehensive health syste...
# ...                                                  ...
# 48392  At Edward Jones, we help clients achieve their...
# 48393  At Edward Jones, we help clients achieve their...
# 48394  At Edward Jones, we help clients achieve their...
# 48395  At Edward Jones, we help clients achieve their...
# 48396  The Institutional Credit Management (ICM) grou...
#
#                                               extensions  \
# 0      ['21 hours ago', 'Full-time', 'Health insuranc...
# 1      ['17 hours ago', 'Work from home', 'Contractor...
# 2      ['12 hours ago', 'Full-time', 'Health insurance']
# 3      ['10 hours ago', 'Full-time', 'Health insuranc...
# 4      ['18 hours ago', 'Work from home', 'Part-time'...
# ...                                                  ...
# 48392  ['23 hours ago', '76,798–130,764 a year', 'Ful...
# 48393  ['23 hours ago', '106,916–182,047 a year', 'Fu...
# 48394  ['23 hours ago', '106,916–182,047 a year', 'Fu...
# 48395  ['23 hours ago', '106,916–182,047 a year', 'Fu...
# 48396  ['24 hours ago', '105,850–158,780 a year', 'Fu...
#
#                         date_time  commute_time     salary_pay salary_rate  \
# 0      2023-08-03 03:00:09.849838           NaN            NaN         NaN
# 1      2023-08-03 03:00:09.849838           NaN            NaN         NaN
# 2      2023-08-03 03:00:09.849838           NaN            NaN         NaN
# 3      2023-08-03 03:00:09.849838           NaN            NaN         NaN
# 4      2023-08-03 03:00:09.849838           NaN            NaN         NaN
# ...                           ...           ...            ...         ...
# 48392  2022-11-04 03:40:23.706734           NaN   76798–130764      a year
# 48393  2022-11-24 04:00:08.710801           NaN  106916–182047      a year
# 48394  2022-12-07 04:00:12.563831           NaN  106916–182047      a year
# 48395  2022-12-08 04:00:15.975728           NaN  106916–182047      a year
# 48396  2023-01-25 04:00:26.521124           NaN  105850–158780      a year
#
#        salary_avg  salary_min  salary_max  salary_hourly  salary_yearly  \
# 0             NaN         NaN         NaN            NaN            NaN
# 1             NaN         NaN         NaN            NaN            NaN
# 2             NaN         NaN         NaN            NaN            NaN
# 3             NaN         NaN         NaN            NaN            NaN
# 4             NaN         NaN         NaN            NaN            NaN
# ...           ...         ...         ...            ...            ...
# 48392    103781.0     76798.0    130764.0            NaN       103781.0
# 48393    144481.5    106916.0    182047.0            NaN       144481.5
# 48394    144481.5    106916.0    182047.0            NaN       144481.5
# 48395    144481.5    106916.0    182047.0            NaN       144481.5
# 48396    132315.0    105850.0    158780.0            NaN       132315.0
#
#        salary_standardized
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 48392             103781.0
# 48393             144481.5
# 48394             144481.5
# 48395             144481.5
# 48396             132315.0
#
# [48397 rows x 16 columns]

# %%
#Checks the memory usage
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48397 entries, 0 to 48396
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                48397 non-null  object
#  1   company_name         48397 non-null  object
#  2   location             48362 non-null  object
#  3   via                  48388 non-null  object
#  4   description          48397 non-null  object
#  5   extensions           48397 non-null  object
#  6   commute_time         0 non-null      float64
#  7   salary_pay           8300 non-null   object
#  8   salary_rate          8300 non-null   object
#  9   salary_avg           8300 non-null   float64
#  10  salary_min           7845 non-null   float64
#  11  salary_max           7845 non-null   float64
#  12  salary_hourly        5210 non-null   float64
#  13  salary_yearly        3063 non-null   float64
#  14  salary_standardized  8300 non-null   float64
# dtypes: float64(7), object(8)
# memory usage: 324.1 MB

# %%
#Displays the total rows and colums of the dataframe
df.shape
# Out:
# (48397, 15)

# %%
# Prints the first five columns of the dataset
df.head()
# Out:
#                                                title      company_name  \
# 0                                       Data Analyst           Chloeta
# 1  Junior Data Analyst/Scientist Role - Contract ...            Upwork
# 2                                       Data Analyst               ATC
# 3                                       Data Analyst        Guidehouse
# 4                                       Data Analyst  AnMed Health LLC
#
#                  location               via  \
# 0    Oklahoma City, OK     via ZipRecruiter
# 1               Anywhere         via Upwork
# 2        United States         via LinkedIn
# 3           Topeka, KS            via Nexxt
# 4               Anywhere       via LinkedIn
#
#                                          description  \
# 0  Job Summary: The Data Analyst oversees data pr...
# 1  Company\n\nThe TAC Index provides independent,...
# 2  Job Title: Entry Level Business Analyst / Prod...
# 3  Job Family :\n\nData Science & Analysis (Digit...
# 4  AnMed is a dynamic, comprehensive health syste...
#
#                                           extensions  commute_time salary_pay  \
# 0  ['21 hours ago', 'Full-time', 'Health insuranc...           NaN        NaN
# 1  ['17 hours ago', 'Work from home', 'Contractor...           NaN        NaN
# 2  ['12 hours ago', 'Full-time', 'Health insurance']           NaN        NaN
# 3  ['10 hours ago', 'Full-time', 'Health insuranc...           NaN        NaN
# 4  ['18 hours ago', 'Work from home', 'Part-time'...           NaN        NaN
#
#   salary_rate  salary_avg  salary_min  salary_max  salary_hourly  \
# 0         NaN         NaN         NaN         NaN            NaN
# 1         NaN         NaN         NaN         NaN            NaN
# 2         NaN         NaN         NaN         NaN            NaN
# 3         NaN         NaN         NaN         NaN            NaN
# 4         NaN         NaN         NaN         NaN            NaN
#
#    salary_yearly  salary_standardized
# 0            NaN                  NaN
# 1            NaN                  NaN
# 2            NaN                  NaN
# 3            NaN                  NaN
# 4            NaN                  NaN

# %%
df.columns
# Out:
# Index(['title', 'company_name', 'location', 'via', 'description', 'extensions',
#        'commute_time', 'salary_pay', 'salary_rate', 'salary_avg', 'salary_min',
#        'salary_max', 'salary_hourly', 'salary_yearly', 'salary_standardized'],
#       dtype='object')

# %%
df.dtypes
# Out:
# title                   object
# company_name            object
# location                object
# via                     object
# description             object
# extensions              object
# commute_time           float64
# salary_pay              object
# salary_rate             object
# salary_avg             float64
# salary_min             float64
# salary_max             float64
# salary_hourly          float64
# salary_yearly          float64
# salary_standardized    float64
# dtype: object

# %%
#Displays the estimate of all columns
df.describe()
# Out:
#        commute_time     salary_avg     salary_min     salary_max  \
# count           0.0    8300.000000    7845.000000    7845.000000
# mean            NaN   37724.512387   31305.770416   44781.575437
# std             NaN   53040.963321   44066.353561   62804.871566
# min             NaN       7.250000       8.000000      10.000000
# 25%             NaN      30.500000      18.460000      44.000000
# 50%             NaN      57.500000      40.000000      75.000000
# 75%             NaN   87725.000000   75000.000000  100000.000000
# max             NaN  300000.000000  275000.000000  346000.000000
#
#        salary_hourly  salary_yearly  salary_standardized
# count    5210.000000    3063.000000          8300.000000
# mean       41.066887  102088.459110         91585.676821
# std        22.621929   32505.611819         43015.342331
# min         7.250000   29289.840000         15080.000000
# 25%        23.500000   80000.000000         62400.000000
# 50%        33.500000   96500.000000         88400.000000
# 75%        56.500000  115000.000000        116480.000000
# max       300.000000  300000.000000        624000.000000

# %%
df.sort_values(by="title", ascending=True).head(20)
# Out:
#                                                    title  \
# 39515                           !! Business Data Analyst
# 5108   "Calling All Analytics Wizards: Recruiting Age...
# 8099   "Data Analyst - Spatial Trend, Sens Slope, Spa...
# 8100   "Data Analyst - Spatial Trend, Sens Slope, Spa...
# 38652                                     "Data Analyst"
# 5136   "Data Magic Wanted: Calling All Analytics Agen...
# 17845  "Excel Data Analyst Needed for Predictive Mode...
# 17844  "Excel Data Analyst Needed for Predictive Mode...
# 44075                                 "GIS Data Analyst"
# 36806  "SPSS Professional Needed: Assistance with Sta...
# 8847   "Seeking Consultation on Big Data Analysis and...
# 44116                                     "data Analyst"
# 20553     #12277 - Business Analyst/Quality Data Analyst
# 29362                             #1271-Forecast Analyst
# 29361                             #1271-Forecast Analyst
# 23207                                #644 - Data Analyst
# 13350                                #683 - Data Analyst
# 13349                                #683 - Data Analyst
# 13348                                #683 - Data Analyst
# 34297                                 #A122 Data Analyst
#
#                       company_name       location  \
# 39515              AppTech Systems       Anywhere
# 5108                        Upwork      Anywhere
# 8099                        Upwork      Anywhere
# 8100                        Upwork      Anywhere
# 38652    Enterprise Solutions Inc.  United States
# 5136                        Upwork      Anywhere
# 17845                       Upwork      Anywhere
# 17844                       Upwork      Anywhere
# 44075                         Dice       Anywhere
# 36806                       Upwork       Anywhere
# 8847                        Upwork      Anywhere
# 44116                         Dice       Anywhere
# 20553                    Qualitest      Anywhere
# 29362                     Bullhorn  United States
# 29361                     Bullhorn  United States
# 23207              Venon Solutions      Anywhere
# 13350              Venon Solutions      Anywhere
# 13349              Venon Solutions      Anywhere
# 13348              Venon Solutions      Anywhere
# 34297  Cameo Consulting Group, LLC       Anywhere
#
#                                    via  \
# 39515                     via LinkedIn
# 5108                        via Upwork
# 8099                        via Upwork
# 8100                        via Upwork
# 38652                     via LinkedIn
# 5136                        via Upwork
# 17845                       via Upwork
# 17844                       via Upwork
# 44075                     via LinkedIn
# 36806                       via Upwork
# 8847                        via Upwork
# 44116                     via LinkedIn
# 20553                     via LinkedIn
# 29362  via Bullhorn Jobs Opportunities
# 29361  via Bullhorn Jobs Opportunities
# 23207                     via LinkedIn
# 13350                     via LinkedIn
# 13349                     via LinkedIn
# 13348                     via LinkedIn
# 34297                       via Indeed
#
#                                              description  \
# 39515  Job Details:\n\nJob Title: Senior Data Analyst...
# 5108   Responsibilities:\n\n1.Data Interpretation: An...
# 8099   I am looking for a skilled Python Code Develop...
# 8100   I am looking for a skilled Python Code Develop...
# 38652  Job Title : Data Analyst\n\nLocation: Redmond,...
# 5136   "Data Alchemy Unleashed: Responsibilities of O...
# 17845  "I am seeking a skilled freelancer to conduct ...
# 17844  "I am seeking a skilled freelancer to conduct ...
# 44075  Dice is the leading career destination for tec...
# 36806  Currently seeking a qualified SPSS professiona...
# 8847   Hello,\n\nI am in possession of extensive data...
# 44116  Dice is the leading career destination for tec...
# 20553  Are you interested in working with the World's...
# 29362  Bullhorn is the global leader in software for ...
# 29361  Bullhorn is the global leader in software for ...
# 23207  Job opportunity only available for Latin Ameri...
# 13350  Job opportunity only available for Latin Ameri...
# 13349  Job opportunity only available for Latin Ameri...
# 13348  Job opportunity only available for Latin Ameri...
# 34297  Cameo Consulting Group, LLC a management consu...
#
#                                               extensions  commute_time  \
# 39515     ['7 hours ago', 'Work from home', 'Full-time']           NaN
# 5108   ['17 hours ago', 'Work from home', 'Contractor...           NaN
# 8099     ['6 hours ago', 'Work from home', 'Contractor']           NaN
# 8100     ['6 hours ago', 'Work from home', 'Contractor']           NaN
# 38652  ['3 hours ago', 'Full-time', 'No degree mentio...           NaN
# 5136   ['19 hours ago', 'Work from home', 'Contractor...           NaN
# 17845  ['17 hours ago', 'Work from home', 'Contractor...           NaN
# 17844  ['17 hours ago', 'Work from home', 'Contractor...           NaN
# 44075   ['19 hours ago', 'Work from home', 'Contractor']           NaN
# 36806   ['16 hours ago', 'Work from home', 'Contractor']           NaN
# 8847   ['19 hours ago', 'Work from home', 'Contractor...           NaN
# 44116  ['19 hours ago', 'Work from home', 'Contractor...           NaN
# 20553  ['12 hours ago', 'Work from home', 'Full-time'...           NaN
# 29362  ['2 hours ago', 'Full-time', 'No degree mentio...           NaN
# 29361  ['2 hours ago', 'Full-time', 'No degree mentio...           NaN
# 23207  ['23 hours ago', 'Work from home', 'Full-time ...           NaN
# 13350  ['23 hours ago', 'Work from home', 'Full-time ...           NaN
# 13349  ['23 hours ago', 'Work from home', 'Full-time ...           NaN
# 13348  ['23 hours ago', 'Work from home', 'Full-time ...           NaN
# 34297  ['9 hours ago', 'Work from home', 'Full-time',...           NaN
#
#       salary_pay salary_rate  salary_avg  salary_min  salary_max  \
# 39515        NaN         NaN         NaN         NaN         NaN
# 5108         NaN         NaN         NaN         NaN         NaN
# 8099         NaN         NaN         NaN         NaN         NaN
# 8100         NaN         NaN         NaN         NaN         NaN
# 38652        NaN         NaN         NaN         NaN         NaN
# 5136         NaN         NaN         NaN         NaN         NaN
# 17845        NaN         NaN         NaN         NaN         NaN
# 17844        NaN         NaN         NaN         NaN         NaN
# 44075        NaN         NaN         NaN         NaN         NaN
# 36806        NaN         NaN         NaN         NaN         NaN
# 8847         NaN         NaN         NaN         NaN         NaN
# 44116        NaN         NaN         NaN         NaN         NaN
# 20553        NaN         NaN         NaN         NaN         NaN
# 29362        NaN         NaN         NaN         NaN         NaN
# 29361        NaN         NaN         NaN         NaN         NaN
# 23207        NaN         NaN         NaN         NaN         NaN
# 13350        NaN         NaN         NaN         NaN         NaN
# 13349        NaN         NaN         NaN         NaN         NaN
# 13348        NaN         NaN         NaN         NaN         NaN
# 34297        NaN         NaN         NaN         NaN         NaN
#
#        salary_hourly  salary_yearly  salary_standardized
# 39515            NaN            NaN                  NaN
# 5108             NaN            NaN                  NaN
# 8099             NaN            NaN                  NaN
# 8100             NaN            NaN                  NaN
# 38652            NaN            NaN                  NaN
# 5136             NaN            NaN                  NaN
# 17845            NaN            NaN                  NaN
# 17844            NaN            NaN                  NaN
# 44075            NaN            NaN                  NaN
# 36806            NaN            NaN                  NaN
# 8847             NaN            NaN                  NaN
# 44116            NaN            NaN                  NaN
# 20553            NaN            NaN                  NaN
# 29362            NaN            NaN                  NaN
# 29361            NaN            NaN                  NaN
# 23207            NaN            NaN                  NaN
# 13350            NaN            NaN                  NaN
# 13349            NaN            NaN                  NaN
# 13348            NaN            NaN                  NaN
# 34297            NaN            NaN                  NaN

# %%
sns.histplot(data=df, x="salary_min", y="salary_max")
# Out:
# /Users/pcordero/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/pcordero/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='salary_min', ylabel='salary_max'>
